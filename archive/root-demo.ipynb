# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot

# %%
import modules.loadroot
q_vals, omega_vals = modules.loadroot.load_events_file("./data/nuwro_testdata/eventsout.root")
plt.hist(q_vals, bins=100, label="q")
plt.hist(omega_vals, bins=100, alpha=0.7, label="omega")
plt.legend()
None

# %%
plt.scatter(q_vals, omega_vals, s=1)
plt.plot([0, 1000], [0,1000], color="red")
plt.ylabel("$\\omega$")
plt.xlabel("q")
# Out:
# Text(0.5, 0, 'q')
